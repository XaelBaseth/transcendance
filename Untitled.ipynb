# %%
[i for i in range (1,15)][:15-2][6:]
# Out:
# [7, 8, 9, 10, 11, 12, 13]

# %%
a,b,c=int(input()),int(input()),int(input())
print(1,'...',end=' ')
L=[i for i in range (1,b)][:b-c+1][2*c:]
for i in L: print(i,end=' ')
print('...',b,end='')
# Out:
#  10
#  15
#  3
# 1 ... 7 8 9 10 11 12 13 ... 15
